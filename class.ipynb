# %% [markdown]
# ## Class and Object

# %%
class Parrot:

    # class attribute
    species = "bird"

    # instance attribute
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
class Parrot:

    # class attribute
    species = "bird"

    # instance attribute
    def __init__(se, name, age): #메소드의 첫번째 인자는 자기 자신을 가르치는 변수
        se.name = name
        se.age = age

# %%
# instantiate the Parrot class
blu = Parrot("Blu", 10)
woo = Parrot("Woo", 15)

# %%
type(blu)
# Out:
# __main__.Parrot

# %%
dir(blu)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name',
#  'species']

# %%
vars(blu) #species는 안나옴.. 인스턴스 애트리뷰트(동적으로 생성한거), 클래스 어트리뷰트(걍 클래스꺼)
# Out:
# {'name': 'Blu', 'age': 10}

# %%
blu.__dict__
# Out:
# {'name': 'Blu', 'age': 10}

# %%
blu.species = 'bird2'

# %%
blu.__dict__
# Out:
# {'name': 'Blu', 'age': 10, 'species': 'bird2'}

# %%
dir(woo)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name',
#  'species']

# %%
 woo.species
# Out:
# 'bird'

# %%
woo.__dict__
# Out:
# {'name': 'Woo', 'age': 15}

# %%
blu.species = 'bird2'

# %%
Parrot.species #클래스 애트리뷰트 접근
# Out:
# 'bird'

# %%
blu.species #인스턴스 어트리뷰트 접근
# Out:
# 'bird2'

# %%
문근영 = Parrot('문근영',30)

# %%
vars(문근영)
# Out:
# {'name': '문근영', 'age': 30}

# %%
문근영.__class__

# %%
# access the class attributes
print("Blu is a {}".format(blu.__class__.species))
print("Woo is also a {}".format(woo.__class__.species))

# access the instance attributes
print("{} is {} years old".format( blu.name, blu.age))
print("{} is {} years old".format( woo.name, woo.age))
# Out:
# Blu is a bird
# Woo is also a bird
# Blu is 10 years old
# Woo is 15 years old

# %% [markdown]
# ## Methods

# %%
class Parrot:
    
    # instance attributes
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    # instance method
    def sing(self, song):
        return "{} sings {}".format(self.name, song)

    def dance(self):
        return "{} is now dancing".format(self.name)
    @classmethod
    def dance2(cls):
        return "{} is now dancing"

# instantiate the object
blu = Parrot("Blu", 10)

# call our instance methods
print(blu.sing("'Happy'"))
print(blu.dance())
# Out:
# Blu sings 'Happy'
# Blu is now dancing

# %%
a = Parrot('sun',42)

# %%
a.dance()
# Out:
# 'sun is now dancing'

# %%
Parrot.dance2() #클래스 메소드는 위와같은 방식이 안댐
# Out:
# '{} is now dancing'

# %%
a.__class__.dance2() #표현방식을 인스턴스처럼..
# Out:
# '{} is now dancing'

# %%
a = Parrot('문근영',30)
b = Parrot('윤하',32)

# %%
Parrot.sing(a, "안편한가봐")
# Out:
# '문근영 sings 안편한가봐'

# %%
b.sing("편한가봐")
# Out:
# '윤하 sings 편한가봐'

# %% [markdown]
# ## Inheritance

# %%
# parent class
class Bird:
    
    def __init__(self):
        print("Bird is ready")

    def whoisThis(self):
        print("Bird")

    def swim(self):
        print("Swim faster")

# child class
class Penguin(Bird):
    def swim(self) :
        print("i can swing swing swing my baby")
    def __init__(self):
        # call super() function
        super(Penguin, self).__init__() #부모꺼도 실행~
        print("Penguin is ready")

#     def whoisThis(self):
#         print("Penguin")

    def run(self):
        print("Run faster")


peggy = Penguin()
# peggy.whoisThis()
# peggy.swim()
# peggy.run()
# Out:
# Bird is ready
# Penguin is ready

# %%
dir(Penguin)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'run',
#  'swim',
#  'whoisThis']

# %% [markdown]
# ## Encapsulation

# %%
class Computer:

    def __init__(self):
        self.__maxprice = 900

    def sell(self):
        print("Selling Price: {}".format(self.__maxprice))

    def setMaxPrice(self, price):
        self.__maxprice = price

c = Computer()
c.sell()

# change the price
c.__maxprice = 1000
c.sell()

# using setter function
c.setMaxPrice(1000)
c.sell()
# Out:
# Selling Price: 900
# Selling Price: 900
# Selling Price: 1000

# %%
dir(Computer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'sell',
#  'setMaxPrice']

# %%
vars(Computer)
# Out:
# mappingproxy({'__module__': '__main__',
#               '__init__': <function __main__.Computer.__init__(self)>,
#               'sell': <function __main__.Computer.sell(self)>,
#               'setMaxPrice': <function __main__.Computer.setMaxPrice(self, price)>,
#               '__dict__': <attribute '__dict__' of 'Computer' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Computer' objects>,
#               '__doc__': None})

# %%
dir() # :현재 네임스페이스 안에 있는 애.. ipython에서만 댐
# Out:
# ['Bird',
#  'Computer',
#  'In',
#  'Out',
#  'Parrot',
#  'Penguin',
#  '_',
#  '_10',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_23',
#  '_24',
#  '_25',
#  '_27',
#  '_34',
#  '_35',
#  '_38',
#  '_39',
#  '_40',
#  '_41',
#  '_42',
#  '_43',
#  '_46',
#  '_5',
#  '_58',
#  '_59',
#  '_6',
#  '_60',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# instantiate the Parrot class\nblu = Parrot("Blu", 10)\nwoo = Parrot("Woo", 15)',
#   'class Parrot:\n\n    # class attribute\n    species = "bird"\n\n    # instance attribute\n    def __init__(self, name, age):\n        self.name = name\n        self.age = age',
#   '# instantiate the Parrot class\nblu = Parrot("Blu", 10)\nwoo = Parrot("Woo", 15)',
#   'type(blue)',
#   'type(blu)',
#   'type(Parrot)',
#   'type(blu)',
#   'type(blu)',
#   'dir(blu)',
#   'dir(blu)',
#   'vars(blue)',
#   'vars(blu)',
#   'vars(blu) #species는 안나옴.. 인스턴스 애트리뷰트(동적으로 생성한거), 클래스 어트리뷰트(걍 클래스꺼)',
#   'blu.__dict__',
#   'blu.__dict__',
#   "blu.species = 'bird2'",
#   'blu.__dict__',
#   'dir(woo)',
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# instantiate the Parrot class\nblu = Parrot("Blu", 10)\nwoo = Parrot("Woo", 15)',
#   'class Parrot:\n\n    # class attribute\n    species = "bird"\n\n    # instance attribute\n    def __init__(self, name, age):\n        self.name = name\n        self.age = age',
#   '# instantiate the Parrot class\nblu = Parrot("Blu", 10)\nwoo = Parrot("Woo", 15)',
#   'type(blue)',
#   'type(blu)',
#   'type(Parrot)',
#   'type(blu)',
#   'type(blu)',
#   'dir(blu)',
#   'dir(blu)',
#   'vars(blue)',
#   'vars(blu)',
#   'vars(blu) #species는 안나옴.. 인스턴스 애트리뷰트(동적으로 생성한거), 클래스 어트리뷰트(걍 클래스꺼)',
#   'blu.__dict__',
#   'blu.__dict__',
#   "blu.species = 'bird2'",
#   'blu.__dict__',
#   'dir(woo)',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-5634c1996fa4> in <module>()
# ----> 1 dis
#
# NameError: name 'dis' is not defined

# %% [markdown]
# ## Polymorphism

# %%
# 다형성 : 원래 상속 기반이지만.. 대리 기법을 통해 
class Parrot:

    def fly(self):
        print("Parrot can fly")
    
    def swim(self):
        print("Parrot can't swim")

class Penguin:

    def fly(self):
        print("Penguin can't fly")
    
    def swim(self):
        print("Penguin can swim")

# common interface
def flying_test(bird):
    bird.fly()

#instantiate objects
blu = Parrot()
peggy = Penguin()

# passing the object
flying_test(blu)
flying_test(peggy)

# 무슨 덕 타이핑 이런게 있다는데 뭐 원래 자바같은데선 상속해서 다형성 안되는걸 되게한다 이런거라는데..
# Out:
# Parrot can fly
# Penguin can't fly

# %%
a = (x for x in range(11))

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-84-15841f3f11d4> in <module>()
# ----> 1 next(a)
#
# StopIteration:

# %%
class Polygon:
    def __init__(self, no_of_sides):
        self.n = no_of_sides
        self.sides = [0 for i in range(no_of_sides)]

    def inputSides(self):
        self.sides = [float(input("Enter side "+str(i+1)+" : ")) for i in range(self.n)]

    def dispSides(self):
        for i in range(self.n):
            print("Side",i+1,"is",self.sides[i])

# %%
class Triangle(Polygon):
    def __init__(self):
        Polygon.__init__(self,3) # super().__init__(3)

    def findArea(self):
        a, b, c = self.sides
        # calculate the semi-perimeter
        s = (a + b + c) / 2
        area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
        print('The area of the triangle is %0.2f' %area)

# %%
# Output: True
print(issubclass(list,object))

# Output: True
print(isinstance(5.5,object))

# Output: True
print(isinstance("Hello",object))
# Out:
# True
# True
# True

# %%
class X: pass
class Y: pass
class Z: pass

class A(X,Y): pass
class B(Y,Z): pass

class M(B,A,Z): pass

# Output:
# [<class '__main__.M'>, <class '__main__.B'>,
# <class '__main__.A'>, <class '__main__.X'>,
# <class '__main__.Y'>, <class '__main__.Z'>,
# <class 'object'>]

print(M.mro())
# Out:
# [<class '__main__.M'>, <class '__main__.B'>, <class '__main__.A'>, <class '__main__.X'>, <class '__main__.Y'>, <class '__main__.Z'>, <class 'object'>]

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return "({0},{1})".format(self.x,self.y)

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return "({0},{1})".format(self.x,self.y)
    
    def __add__(self,other):
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)

# %%
class Point:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def __str__(self):
        return "({0},{1})".format(self.x,self.y)
    
    def __lt__(self,other):
        self_mag = (self.x ** 2) + (self.y ** 2)
        other_mag = (other.x ** 2) + (other.y ** 2)
        return self_mag < other_mag

# %%
class MyINT(int):
    def __add__(self, other):
        super().__add__()

# %%
a = MyINT(3)

# %%
a
# Out:
# 3

# %%
b = MyINT(4)

# %%
b
# Out:
# 4

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-bd58363a63fc> in <module>()
# ----> 1 a + b
#
# <ipython-input-86-9e5f8ba7830e> in __add__(self, other)
#       1 class MyINT(int):
#       2     def __add__(self, other):
# ----> 3         super().__add__()
#
# TypeError: expected 1 arguments, got 0

# %%
class MyINT(int):
    def __add__(self, other):
        super().__add__(self, other)
a = MyINT(3)
b = MyINT(4)

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-bd58363a63fc> in <module>()
# ----> 1 a + b
#
# <ipython-input-86-9e5f8ba7830e> in __add__(self, other)
#       1 class MyINT(int):
#       2     def __add__(self, other):
# ----> 3         super().__add__()
#
# TypeError: expected 1 arguments, got 0

# %%
class MyINT(int):
    def __add__(self, other):
        super().__add__(other)
a = MyINT(3)
b = MyINT(4)

# %%
print(a+b)
# Out:
# None

# %%
a.add(b) # 연산자는 오버로딩
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-74668c488031> in <module>()
# ----> 1 a.add(b) # 연산자는 오버로딩
#
# AttributeError: 'MyINT' object has no attribute 'add'

# %%
class B:
    def __str__(self) :
        #__str__은 print 할때 나오는거, repr은 변수출력할떄 나오는거
        return "aaa" 
    def __repr__(self) :
        #__str__은 print 할때 나오는거, repr은 변수출력할떄 나오는거
        return "bbb"

# %%
class MyINT(int):
    def __add__(self, other):
        #super().__add__(other)
        print('add')
a = MyINT(3)
b = MyINT(4)

# %%
a+b
# Out:
# add

# %%
class MyINT(int):
    def __init__(self,num):
        self.num = num
    def __add__(self, other):
        #super().__add__(other)
        print('add')
        return self.num+other
a = MyINT(3)
b = MyINT(4)

# %%
a+b
# Out:
# add
# 7

# %%
class MyINT(int):
    def __init__(self,num):
        self.num = num
    def __add__(self, other):
        #super().__add__(other)
        print('add')
        return self.num+other
    def __str__(self):
        print('I won\'t let you know ')
a = MyINT(3)
b = MyINT(4)

# %%
print(a+b) #왜 str 안나오냐!
# Out:
# add
# 7

# %%
3 .__str__() #str로 형변환 된다 print찍을려면..
# Out:
# '3'

# %%
class MyINT(int):
    def __init__(self,num):
        self.num = num
    def __add__(self, other):
        #super().__add__(other)
        print('add')
        return self.num+other
    def __str__(self,*args,**kwargs): # 쉬프트탭해보면 인자 모양이 다르다. 모양이 똑같아야 오버라이딩 된다..
        print('I won\'t let you know ')
    def __radd__(self,other):
        return self.num+other+1
a = MyINT(3)
b = MyINT(4)

# %%
MyINT(2)+MyINT(1)
# Out:
# add
# 4

# %%
print(a+b)
# Out:
# add
# 7

# %%
class AA:
    def __init__(self,num):
        self.num = num
    def __add__(self,other):
        self.num = self.num+other.num
    def __str__(self):
        return(self.num)

# %%
aa = AA(3)

# %%
bb = AA(4)

# %%
aa+bb #걍 클래스 만들면object에 __add__없네.. 그래서 __add__오버로딩해주고

# %%
print(aa+bb) #__str__넣어줘야 print찍을 수 있다
# Out:
# None

# %%
from keyword import main

# %%
# %whos
# Out:
# Variable      Type        Data/Info
# -----------------------------------
# AA            type        <class '__main__.AA'>
# B             type        <class '__main__.B'>
# Bird          type        <class '__main__.Bird'>
# Computer      type        <class '__main__.Computer'>
# MyINT         type        <class '__main__.MyINT'>
# Parrot        type        <class '__main__.Parrot'>
# Penguin       type        <class '__main__.Penguin'>
# a             MyINT       I won't let you know
# <object with id 1961675499272 (str() failed)>
# aa            AA          <object with id 1961675503040 (str() failed)>
# b             MyINT       I won't let you know
# <object with id 1961675384712 (str() failed)>
# bb            AA          <object with id 1961675501920 (str() failed)>
# blu           Parrot      <__main__.Parrot object at 0x000001C8BCF5E438>
# c             Computer    <__main__.Computer object at 0x000001C8BCF4ABE0>
# ...

# %%
from collections import Callable

# %%
import keyword

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
callable(keyword.kwlist)
# Out:
# False

# %%
class A:
    a = ['a', 'b', 'c']
    @property
    def x(self):
        self.a=a
        return self.a

# %%
a = A()

# %%
callable(a.x)
# Out:
# False

# %%
a.x.__call__()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-f21c07e59a77> in <module>()
# ----> 1 a.x.__call__()
#
# AttributeError: 'A' object has no attribute '__call__'

# %%
from collections import Callable

# %%
type(Callable)
# Out:
# abc.ABCMeta

# %%
from collections import namedtuple

# %%
print(namedtuple.__doc__)
# Out:
# Returns a new subclass of tuple with named fields.
#
#     >>> Point = namedtuple('Point', ['x', 'y'])
#     >>> Point.__doc__                   # docstring for the new class
#     'Point(x, y)'
#     >>> p = Point(11, y=22)             # instantiate with positional args or keywords
#     >>> p[0] + p[1]                     # indexable like a plain tuple
#     33
#     >>> x, y = p                        # unpack like a regular tuple
#     >>> x, y
#     (11, 22)
#     >>> p.x + p.y                       # fields also accessible by name
#     33
#     >>> d = p._asdict()                 # convert to a dictionary
#     >>> d['x']
#     11
#     >>> Point(**d)                      # convert from a dictionary
#     Point(x=11, y=22)
#     >>> p._replace(x=100)               # _replace() is like str.replace() but targets named fields
#     Point(x=100, y=22)

# %%
a = namedtuple('연예인',['이름','나이','성별'])

# %%
a #namedtuple은 클래스를 만들어주는거다 : 팩토리 패턴을 사용
# Out:
# __main__.연예인

# %%
x = a('문근영','29','여')
x
# Out:
# 연예인(이름='문근영', 나이='29', 성별='여')

# %%
x[0]
# Out:
# '문근영'

# %%
y = a('김근영','27','남')

# %%
L = [x,y]

# %%
sum([int(x.나이) for x in L])
# Out:
# 56

# %%
from collections import OrderedDict

# %%
issubclass(OrderedDict,dict)
# Out:
# True

# %%
dir(OrderedDict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'move_to_end',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
a = OrderedDict(name='문근영',age=20)

# %%
help(OrderedDict)
# Out:
# Help on class OrderedDict in module collections:
#
# class OrderedDict(builtins.dict)
#  |  Dictionary that remembers insertion order
#  |
#  |  Method resolution order:
#  |      OrderedDict
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
# ...

# %%
a.update()

# %%
print(a)
# Out:
# OrderedDict([('name', '문근영'), ('age', 20)])
