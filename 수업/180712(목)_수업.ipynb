# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%writefile test.html
# <!docktype html>
# <html lang="ko">
#     <head>
#         <meta charset="UTF-8"/>
#         <title>예제</title>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" /> #무슨 모바일 최적화인가..??
#         <meta name="keywords" content="실습, 데이터진흥원, 노잼" />
#         <script></script>
#         <style></style>
#     </head>
#     <body>
#         <ul>
#             <li>
#
#             첫번째
#             </li>
#             <li>두번째</li>
#             <li>세번째</li>
#         </ul>
#         <ol>
#             <li>첫번째</li>
#             <li>두번째</li>
#             <li>세번째</li>
#         </ol>
#         <p>
#             <img src="data:image/jpeg;base64,..."
#             usemap = "#test" />
#         </p>
#         <map name="test">
#             <area shape="rect" coords ="0,0,100,100" alt="도움말1" href="http://naver.com"/>
#             #<area shape="rect" coords ="10,10,20,20" alt="도움말2" href="http://naver.com"/>
#             #<area shape="rect" coords ="20,20,30,30" alt="도움말3" href="http://naver.com"/>
#         </map>
#         <h1>첫번째 예제</h1>
#         <h2>첫번째 예제</h2>
#         <h3>첫번째 예제</h3>
#         <h4>첫번째 예제</h4>
#         <h5>첫번째 예제</h5>
#         <h6>첫번째 예제</h6>
#         <section>
#             <article>
#                 <h1>제목</h1>
#                 <p>내용</p>
#             </article>
#             <article>
#                 <h1>제목</h1>
#                 <p>내용
#                     단락<br/><br/>="\n\n나누고싶다"<br/>
#                     <a href="http://naver.com" target="_self">내 페이지가 바뀌는 링크</a>
#                     <a href="http://naver.com" target="_blank">새 페이지가 뜨는 링크</a>
#                 </p>
#                 <pre> 내용
#                  pre는 눈에
#                         보이는 </div>대로
#                          #import math 나온다!
#                             나온다..
#                 </pre>
#             </article>
#     </body>
# </html>
# Out:
# Overwriting test.html

# %% [markdown]
# Layout (2 Column with Header and Footer)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%writefile test1.html
# <!docktype html>
# <html lang="ko">
#     <head>
#         <meta charset="UTF-8"/>
#         <title>예제1</title>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#         <meta name="keywords" content="실습, 데이터진흥원, 노잼" />
#         <script></script>
#         <style></style>
#     </head>
#     <body>
#         <header>
#             <nav>
#                 <ul>
#                     <li>News</li>
#                     <li>Contact</li>
#                     <li>About</li>
#                 </ul>
#             </nav>
#         </header>
#         <section>
#             <article>
#                 <h1>1. Title</h1>
#                 <p>Content</p>
#             </article>
#             <article>
#                 <h1>2. Title</h1>
#                 <section>
#                     <h1>2.1 Sub Title1</h1>
#                     <p>Sub Content1</p>
#                 </section>
#                 <section>
#                     <h1>2.2 Sub Title2</h1>
#                     <p>Sub content2</p>
#                 </section>
#             </article>
#         </section>
#         <aside>
#             <section>
#                 <h1>Advertisement</h1>
#                 <p>Content</p>
#             </section>
#             <section>
#                 <h1>Advertisement</h1>
#                 <p>Content</p>
#             </section>
#         </aside>
#         <footer>
#         </footer>
#     </body>
# </html>
# Out:
# Overwriting test1.html

# %%
# %%writefile test2-css.html
# <!docktype html>
# <html lang="ko">
#     <head>
#         <meta charset="UTF-8"/>
#         <title>예제1</title>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#         <meta name="keywords" content="실습, 데이터진흥원, 노잼" />
#         <script></script>
#         <style>
#             div {border:1px solid #aaaaaa}
#             #id {color:rgb(0,0,255);}
#             .class {background-color:yellow;}
#             div + p.class {background-color:green;}
#
#         </style>
#     </head>
#     <body>
#         <div id="id">Content1</div>
#         <div class="class">Content2</div>
#         <p class="class">Content3</p>
#     </body>
# </html>
# Out:
# Overwriting test2-css.html

# %% [markdown]
# ![image.png](attachment:image.png)
# - 정렬에 관한 CSS 명령어들

# %%
# %%writefile test3-css.html
# <!docktype html>
# <html lang="ko">
#     <head>
#         <meta charset="UTF-8"/>
#         <title>예제1</title>
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#         <script></script>
#         <style>
#             div {border:1px solid #aaaaaa;}
#             #id1 {height:1000px;}
#             #id2 {position:absolute;top:100px;left:200px;}
#             #id3 {position:fixed;top:100px;left:200px;}
#
#         </style>
#     </head>
#     <body>
#         <div id="id1">Content1</div>
#         <div id="id2">Content2</div>
#         <div id="id3">Content3</p>
#     </body>
# </html>
# Out:
# Writing test3-css.html
