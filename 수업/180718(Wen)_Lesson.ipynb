# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\hangs\anaconda3\lib\site-packages (3.7.1)
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
client = MongoClient('127.0.0.1')

# %%
client.HOST
# Out:
# 'localhost'

# %%
client.PORT
# Out:
# 27017

# %%
client.server_info()
# Out:
# {'version': '4.0.0',
#  'gitVersion': '3b07af3d4f471ae89e8186d33bbb1d5259597d51',
#  'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#  'modules': [],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [4, 0, 0, 0],
#  'openssl': {'running': 'Windows SChannel'},
#  'buildEnvironment': {'distmod': '2008plus-ssl',
#   'distarch': 'x86_64',
#   'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.00.24223 for x64',
#   'ccflags': '/nologo /EHsc /W3 /wd4355 /wd4800 /wd4267 /wd4244 /wd4290 /wd4068 /wd4351 /wd4373 /we4013 /we4099 /we4930 /WX /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /Zc:rvalueCast /Zc:strictStrings /volatile:iso /Gw /Gy /Zc:inline',
#   'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.00.24223 for x64',
#   'cxxflags': '/TP',
#   'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#   'target_arch': 'x86_64',
#   'target_os': 'windows'},
#  'bits': 64,
#  'debug': False,
#  'maxBsonObjectSize': 16777216,
#  'storageEngines': ['devnull', 'ephemeralForTest', 'mmapv1', 'wiredTiger'],
#  'ok': 1.0}

# %%
client.list_database_names()
# Out:
# ['HomeworkDB', 'admin', 'config', 'local', 'newDB', 'sns', 'test']

# %%
list_db = client.list_databases()

# %%
list_db

# %%
list(list_db)
# Out:
# [{'name': 'HomeworkDB', 'sizeOnDisk': 155648.0, 'empty': False},
#  {'name': 'admin', 'sizeOnDisk': 176128.0, 'empty': False},
#  {'name': 'config', 'sizeOnDisk': 49152.0, 'empty': False},
#  {'name': 'local', 'sizeOnDisk': 65536.0, 'empty': False},
#  {'name': 'newDB', 'sizeOnDisk': 40960.0, 'empty': False},
#  {'name': 'sns', 'sizeOnDisk': 90112.0, 'empty': False},
#  {'name': 'test', 'sizeOnDisk': 524288.0, 'empty': False}]

# %%
list(list_db)
# Out:
# []

# %% [markdown]
# ## 왜? client.list_dbabase()는 command_cursor라서 데이터베이스리스트의 최상단을 가리키다가 넘어감..

# %%
for i in list_db:
    print(i)
    print(type(i))
# Out:
# {'name': 'HomeworkDB', 'sizeOnDisk': 155648.0, 'empty': False}
# <class 'dict'>
# {'name': 'admin', 'sizeOnDisk': 176128.0, 'empty': False}
# <class 'dict'>
# {'name': 'config', 'sizeOnDisk': 49152.0, 'empty': False}
# <class 'dict'>
# {'name': 'local', 'sizeOnDisk': 65536.0, 'empty': False}
# <class 'dict'>
# {'name': 'newDB', 'sizeOnDisk': 40960.0, 'empty': False}
# <class 'dict'>
# {'name': 'sns', 'sizeOnDisk': 90112.0, 'empty': False}
# <class 'dict'>
# {'name': 'test', 'sizeOnDisk': 524288.0, 'empty': False}
# <class 'dict'>

# %%
admin = client.get_database('admin')

# %%
admin.list_collection_names()
# Out:
# ['system.users', 'system.version']

# %%
test = client.get_database('test')

# %%
test2 = client.test

# %%
test3 = client['test']

# %%
item = test.get_collection('item')

# %%
item
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'test'), 'item')

# %%
test2 = test.item

# %%
test['item']
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'test'), 'item')

# %%
newitem = {'name':'Item1',
          'price': 10000,
          'ratio' : 4.5}

# %%
item.insert_one(newitem)

# %%
result = item.find({})

# %%
result

# %%
list(result)
# Out:
# [{'_id': ObjectId('5b45aab564aa15b0fbea9040'),
#   'name': 'item 0',
#   'price': 35326},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9041'),
#   'name': 'item 1',
#   'price': 34764},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9042'),
#   'name': 'item 2',
#   'price': 44743},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9043'),
#   'name': 'item 3',
#   'price': 10893},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9044'),
#   'name': 'item 4',
#   'price': 25189},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9045'),
#   'name': 'item 5',
#   'price': 35036},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9046'),
#   'name': 'item 6',
#   'price': 36965},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9047'),
#   'name': 'item 7',
#   'price': 12662},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9048'),
#   'name': 'item 8',
#   'price': 8875},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9049'),
#   'name': 'item 9',
#   'price': 2387},
#  {'_id': ObjectId('5b45aab564aa15b0fbea904a'),
#   'name': 'item 10',
#   'price': 6104},
#  {'_id': ObjectId('5b45aab564aa15b0fbea904b'),
#   'name': 'item 11',
#   'price': 29492},
#  {'_id': ObjectId('5b45aab564aa15b0fbea904c'),
#   'name': 'item 12',
#   'price': 10201},
#  {'_id': ObjectId('5b45aab564aa15b0fbea904d'),
#   'name': 'item 13',
#   'price': 47759},
#  {'_id': ObjectId('5b45aab564aa15b0fbea904e'),
#   'name': 'item 14',
#   'price': 666},
#  {'_id': ObjectId('5b45aab564aa15b0fbea904f'),
#   'name': 'item 15',
#   'price': 37354},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9050'),
#   'name': 'item 16',
#   'price': 25159},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9051'),
#   'name': 'item 17',
#   'price': 39315},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9052'),
#   'name': 'item 18',
#   'price': 26874},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9053'),
#   'name': 'item 19',
#   'price': 26051},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9054'),
#   'name': 'item 20',
#   'price': 7922},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9055'),
#   'name': 'item 21',
#   'price': 32870},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9056'),
#   'name': 'item 22',
#   'price': 46075},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9057'),
#   'name': 'item 23',
#   'price': 49324},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9058'),
#   'name': 'item 24',
#   'price': 25092},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9059'),
#   'name': 'item 25',
#   'price': 13930},
#  {'_id': ObjectId('5b45aab564aa15b0fbea905a'),
#   'name': 'item 26',
#   'price': 45024},
#  {'_id': ObjectId('5b45aab564aa15b0fbea905b'),
#   'name': 'item 27',
#   'price': 1239},
#  {'_id': ObjectId('5b45aab564aa15b0fbea905c'),
#   'name': 'item 28',
#   'price': 42119},
#  {'_id': ObjectId('5b45aab564aa15b0fbea905d'),
#   'name': 'item 29',
#   'price': 34972},
#  {'_id': ObjectId('5b45aab564aa15b0fbea905e'),
#   'name': 'item 30',
#   'price': 29230},
#  {'_id': ObjectId('5b45aab564aa15b0fbea905f'),
#   'name': 'item 31',
#   'price': 25812},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9060'),
#   'name': 'item 32',
#   'price': 7879},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9061'),
#   'name': 'item 33',
#   'price': 1786},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9062'),
#   'name': 'item 34',
#   'price': 23911},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9063'),
#   'name': 'item 35',
#   'price': 25830},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9064'),
#   'name': 'item 36',
#   'price': 6830},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9065'),
#   'name': 'item 37',
#   'price': 37882},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9066'),
#   'name': 'item 38',
#   'price': 12213},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9067'),
#   'name': 'item 39',
#   'price': 35048},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9068'),
#   'name': 'item 40',
#   'price': 40589},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9069'),
#   'name': 'item 41',
#   'price': 31345},
#  {'_id': ObjectId('5b45aab564aa15b0fbea906a'),
#   'name': 'item 42',
#   'price': 9701},
#  {'_id': ObjectId('5b45aab564aa15b0fbea906b'),
#   'name': 'item 43',
#   'price': 22156},
#  {'_id': ObjectId('5b45aab564aa15b0fbea906c'),
#   'name': 'item 44',
#   'price': 39421},
#  {'_id': ObjectId('5b45aab564aa15b0fbea906d'),
#   'name': 'item 45',
#   'price': 45582},
#  {'_id': ObjectId('5b45aab564aa15b0fbea906e'),
#   'name': 'item 46',
#   'price': 39289},
#  {'_id': ObjectId('5b45aab564aa15b0fbea906f'),
#   'name': 'item 47',
#   'price': 5823},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9070'),
#   'name': 'item 48',
#   'price': 24744},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9071'),
#   'name': 'item 49',
#   'price': 834},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9072'),
#   'name': 'item 50',
#   'price': 31506},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9073'),
#   'name': 'item 51',
#   'price': 37859},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9074'),
#   'name': 'item 52',
#   'price': 36403},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9075'),
#   'name': 'item 53',
#   'price': 32857},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9076'),
#   'name': 'item 54',
#   'price': 11490},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9077'),
#   'name': 'item 55',
#   'price': 4584},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9078'),
#   'name': 'item 56',
#   'price': 5348},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9079'),
#   'name': 'item 57',
#   'price': 36494},
#  {'_id': ObjectId('5b45aab564aa15b0fbea907a'),
#   'name': 'item 58',
#   'price': 43858},
#  {'_id': ObjectId('5b45aab564aa15b0fbea907b'),
#   'name': 'item 59',
#   'price': 11686},
#  {'_id': ObjectId('5b45aab564aa15b0fbea907c'),
#   'name': 'item 60',
#   'price': 33203},
#  {'_id': ObjectId('5b45aab564aa15b0fbea907d'),
#   'name': 'item 61',
#   'price': 31399},
#  {'_id': ObjectId('5b45aab564aa15b0fbea907e'),
#   'name': 'item 62',
#   'price': 15464},
#  {'_id': ObjectId('5b45aab564aa15b0fbea907f'),
#   'name': 'item 63',
#   'price': 2352},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9080'),
#   'name': 'item 64',
#   'price': 12942},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9081'),
#   'name': 'item 65',
#   'price': 49275},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9082'),
#   'name': 'item 66',
#   'price': 17448},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9083'),
#   'name': 'item 67',
#   'price': 2651},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9084'),
#   'name': 'item 68',
#   'price': 21251},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9085'),
#   'name': 'item 69',
#   'price': 14557},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9086'),
#   'name': 'item 70',
#   'price': 36162},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9087'),
#   'name': 'item 71',
#   'price': 34689},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9088'),
#   'name': 'item 72',
#   'price': 48785},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9089'),
#   'name': 'item 73',
#   'price': 7157},
#  {'_id': ObjectId('5b45aab564aa15b0fbea908a'),
#   'name': 'item 74',
#   'price': 27899},
#  {'_id': ObjectId('5b45aab564aa15b0fbea908b'),
#   'name': 'item 75',
#   'price': 21908},
#  {'_id': ObjectId('5b45aab564aa15b0fbea908c'),
#   'name': 'item 76',
#   'price': 25451},
#  {'_id': ObjectId('5b45aab564aa15b0fbea908d'),
#   'name': 'item 77',
#   'price': 45211},
#  {'_id': ObjectId('5b45aab564aa15b0fbea908e'),
#   'name': 'item 78',
#   'price': 42253},
#  {'_id': ObjectId('5b45aab564aa15b0fbea908f'),
#   'name': 'item 79',
#   'price': 32707},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9090'),
#   'name': 'item 80',
#   'price': 29904},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9091'),
#   'name': 'item 81',
#   'price': 767},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9092'),
#   'name': 'item 82',
#   'price': 34177},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9093'),
#   'name': 'item 83',
#   'price': 7510},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9094'),
#   'name': 'item 84',
#   'price': 39547},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9095'),
#   'name': 'item 85',
#   'price': 35748},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9096'),
#   'name': 'item 86',
#   'price': 1115},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9097'),
#   'name': 'item 87',
#   'price': 8700},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9098'),
#   'name': 'item 88',
#   'price': 14501},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9099'),
#   'name': 'item 89',
#   'price': 16312},
#  {'_id': ObjectId('5b45aab564aa15b0fbea909a'),
#   'name': 'item 90',
#   'price': 3352},
#  {'_id': ObjectId('5b45aab564aa15b0fbea909b'),
#   'name': 'item 91',
#   'price': 7145},
#  {'_id': ObjectId('5b45aab564aa15b0fbea909c'),
#   'name': 'item 92',
#   'price': 47121},
#  {'_id': ObjectId('5b45aab564aa15b0fbea909d'),
#   'name': 'item 93',
#   'price': 44600},
#  {'_id': ObjectId('5b45aab564aa15b0fbea909e'),
#   'name': 'item 94',
#   'price': 10966},
#  {'_id': ObjectId('5b45aab564aa15b0fbea909f'),
#   'name': 'item 95',
#   'price': 11081},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a0'),
#   'name': 'item 96',
#   'price': 41238},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a1'),
#   'name': 'item 97',
#   'price': 41537},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a2'),
#   'name': 'item 98',
#   'price': 26835},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a3'),
#   'name': 'item 99',
#   'price': 48707},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a4'),
#   'name': 'item 100',
#   'price': 37097},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a5'),
#   'name': 'item 101',
#   'price': 31738},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a6'),
#   'name': 'item 102',
#   'price': 14438},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a7'),
#   'name': 'item 103',
#   'price': 34827},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a8'),
#   'name': 'item 104',
#   'price': 37148},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90a9'),
#   'name': 'item 105',
#   'price': 32133},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90aa'),
#   'name': 'item 106',
#   'price': 37277},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ab'),
#   'name': 'item 107',
#   'price': 16415},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ac'),
#   'name': 'item 108',
#   'price': 7443},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ad'),
#   'name': 'item 109',
#   'price': 4582},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ae'),
#   'name': 'item 110',
#   'price': 11220},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90af'),
#   'name': 'item 111',
#   'price': 26773},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b0'),
#   'name': 'item 112',
#   'price': 30896},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b1'),
#   'name': 'item 113',
#   'price': 30287},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b2'),
#   'name': 'item 114',
#   'price': 11816},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b3'),
#   'name': 'item 115',
#   'price': 29905},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b4'),
#   'name': 'item 116',
#   'price': 42200},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b5'),
#   'name': 'item 117',
#   'price': 17377},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b6'),
#   'name': 'item 118',
#   'price': 23779},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b7'),
#   'name': 'item 119',
#   'price': 1778},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b8'),
#   'name': 'item 120',
#   'price': 47806},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90b9'),
#   'name': 'item 121',
#   'price': 11763},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ba'),
#   'name': 'item 122',
#   'price': 28284},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90bb'),
#   'name': 'item 123',
#   'price': 25},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90bc'),
#   'name': 'item 124',
#   'price': 8709},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90bd'),
#   'name': 'item 125',
#   'price': 18455},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90be'),
#   'name': 'item 126',
#   'price': 422},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90bf'),
#   'name': 'item 127',
#   'price': 40581},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c0'),
#   'name': 'item 128',
#   'price': 17031},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c1'),
#   'name': 'item 129',
#   'price': 21887},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c2'),
#   'name': 'item 130',
#   'price': 17764},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c3'),
#   'name': 'item 131',
#   'price': 49955},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c4'),
#   'name': 'item 132',
#   'price': 34587},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c5'),
#   'name': 'item 133',
#   'price': 5361},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c6'),
#   'name': 'item 134',
#   'price': 42703},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c7'),
#   'name': 'item 135',
#   'price': 46088},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c8'),
#   'name': 'item 136',
#   'price': 3500},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90c9'),
#   'name': 'item 137',
#   'price': 36435},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ca'),
#   'name': 'item 138',
#   'price': 47948},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90cb'),
#   'name': 'item 139',
#   'price': 22416},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90cc'),
#   'name': 'item 140',
#   'price': 42911},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90cd'),
#   'name': 'item 141',
#   'price': 3604},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ce'),
#   'name': 'item 142',
#   'price': 37685},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90cf'),
#   'name': 'item 143',
#   'price': 33199},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d0'),
#   'name': 'item 144',
#   'price': 5212},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d1'),
#   'name': 'item 145',
#   'price': 19804},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d2'),
#   'name': 'item 146',
#   'price': 29649},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d3'),
#   'name': 'item 147',
#   'price': 233},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d4'),
#   'name': 'item 148',
#   'price': 28873},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d5'),
#   'name': 'item 149',
#   'price': 2483},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d6'),
#   'name': 'item 150',
#   'price': 4166},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d7'),
#   'name': 'item 151',
#   'price': 43298},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d8'),
#   'name': 'item 152',
#   'price': 42973},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90d9'),
#   'name': 'item 153',
#   'price': 25810},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90da'),
#   'name': 'item 154',
#   'price': 43632},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90db'),
#   'name': 'item 155',
#   'price': 27341},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90dc'),
#   'name': 'item 156',
#   'price': 34457},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90dd'),
#   'name': 'item 157',
#   'price': 20882},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90de'),
#   'name': 'item 158',
#   'price': 6706},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90df'),
#   'name': 'item 159',
#   'price': 16625},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e0'),
#   'name': 'item 160',
#   'price': 9379},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e1'),
#   'name': 'item 161',
#   'price': 12870},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e2'),
#   'name': 'item 162',
#   'price': 35278},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e3'),
#   'name': 'item 163',
#   'price': 12895},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e4'),
#   'name': 'item 164',
#   'price': 18602},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e5'),
#   'name': 'item 165',
#   'price': 2994},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e6'),
#   'name': 'item 166',
#   'price': 48763},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e7'),
#   'name': 'item 167',
#   'price': 18261},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e8'),
#   'name': 'item 168',
#   'price': 41967},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90e9'),
#   'name': 'item 169',
#   'price': 5581},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ea'),
#   'name': 'item 170',
#   'price': 35696},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90eb'),
#   'name': 'item 171',
#   'price': 2174},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ec'),
#   'name': 'item 172',
#   'price': 12612},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ed'),
#   'name': 'item 173',
#   'price': 48697},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ee'),
#   'name': 'item 174',
#   'price': 10719},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ef'),
#   'name': 'item 175',
#   'price': 7716},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f0'),
#   'name': 'item 176',
#   'price': 35027},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f1'),
#   'name': 'item 177',
#   'price': 11625},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f2'),
#   'name': 'item 178',
#   'price': 47643},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f3'),
#   'name': 'item 179',
#   'price': 40382},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f4'),
#   'name': 'item 180',
#   'price': 2837},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f5'),
#   'name': 'item 181',
#   'price': 43784},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f6'),
#   'name': 'item 182',
#   'price': 12805},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f7'),
#   'name': 'item 183',
#   'price': 47939},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f8'),
#   'name': 'item 184',
#   'price': 40292},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90f9'),
#   'name': 'item 185',
#   'price': 9571},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90fa'),
#   'name': 'item 186',
#   'price': 43450},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90fb'),
#   'name': 'item 187',
#   'price': 12949},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90fc'),
#   'name': 'item 188',
#   'price': 14815},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90fd'),
#   'name': 'item 189',
#   'price': 42546},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90fe'),
#   'name': 'item 190',
#   'price': 7914},
#  {'_id': ObjectId('5b45aab564aa15b0fbea90ff'),
#   'name': 'item 191',
#   'price': 28766},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9100'),
#   'name': 'item 192',
#   'price': 36708},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9101'),
#   'name': 'item 193',
#   'price': 43491},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9102'),
#   'name': 'item 194',
#   'price': 6891},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9103'),
#   'name': 'item 195',
#   'price': 10499},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9104'),
#   'name': 'item 196',
#   'price': 17714},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9105'),
#   'name': 'item 197',
#   'price': 34595},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9106'),
#   'name': 'item 198',
#   'price': 26136},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9107'),
#   'name': 'item 199',
#   'price': 34003},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9108'),
#   'name': 'item 200',
#   'price': 39953},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9109'),
#   'name': 'item 201',
#   'price': 48407},
#  {'_id': ObjectId('5b45aab564aa15b0fbea910a'),
#   'name': 'item 202',
#   'price': 18086},
#  {'_id': ObjectId('5b45aab564aa15b0fbea910b'),
#   'name': 'item 203',
#   'price': 46179},
#  {'_id': ObjectId('5b45aab564aa15b0fbea910c'),
#   'name': 'item 204',
#   'price': 30464},
#  {'_id': ObjectId('5b45aab564aa15b0fbea910d'),
#   'name': 'item 205',
#   'price': 1465},
#  {'_id': ObjectId('5b45aab564aa15b0fbea910e'),
#   'name': 'item 206',
#   'price': 40092},
#  {'_id': ObjectId('5b45aab564aa15b0fbea910f'),
#   'name': 'item 207',
#   'price': 7484},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9110'),
#   'name': 'item 208',
#   'price': 22052},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9111'),
#   'name': 'item 209',
#   'price': 1904},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9112'),
#   'name': 'item 210',
#   'price': 48354},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9113'),
#   'name': 'item 211',
#   'price': 11294},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9114'),
#   'name': 'item 212',
#   'price': 5552},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9115'),
#   'name': 'item 213',
#   'price': 30589},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9116'),
#   'name': 'item 214',
#   'price': 44965},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9117'),
#   'name': 'item 215',
#   'price': 3989},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9118'),
#   'name': 'item 216',
#   'price': 5418},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9119'),
#   'name': 'item 217',
#   'price': 44424},
#  {'_id': ObjectId('5b45aab564aa15b0fbea911a'),
#   'name': 'item 218',
#   'price': 12051},
#  {'_id': ObjectId('5b45aab564aa15b0fbea911b'),
#   'name': 'item 219',
#   'price': 13629},
#  {'_id': ObjectId('5b45aab564aa15b0fbea911c'),
#   'name': 'item 220',
#   'price': 32715},
#  {'_id': ObjectId('5b45aab564aa15b0fbea911d'),
#   'name': 'item 221',
#   'price': 5768},
#  {'_id': ObjectId('5b45aab564aa15b0fbea911e'),
#   'name': 'item 222',
#   'price': 49470},
#  {'_id': ObjectId('5b45aab564aa15b0fbea911f'),
#   'name': 'item 223',
#   'price': 43289},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9120'),
#   'name': 'item 224',
#   'price': 47879},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9121'),
#   'name': 'item 225',
#   'price': 33244},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9122'),
#   'name': 'item 226',
#   'price': 18977},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9123'),
#   'name': 'item 227',
#   'price': 22628},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9124'),
#   'name': 'item 228',
#   'price': 32082},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9125'),
#   'name': 'item 229',
#   'price': 28862},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9126'),
#   'name': 'item 230',
#   'price': 31583},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9127'),
#   'name': 'item 231',
#   'price': 29774},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9128'),
#   'name': 'item 232',
#   'price': 4158},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9129'),
#   'name': 'item 233',
#   'price': 32185},
#  {'_id': ObjectId('5b45aab564aa15b0fbea912a'),
#   'name': 'item 234',
#   'price': 5395},
#  {'_id': ObjectId('5b45aab564aa15b0fbea912b'),
#   'name': 'item 235',
#   'price': 6923},
#  {'_id': ObjectId('5b45aab564aa15b0fbea912c'),
#   'name': 'item 236',
#   'price': 34868},
#  {'_id': ObjectId('5b45aab564aa15b0fbea912d'),
#   'name': 'item 237',
#   'price': 20785},
#  {'_id': ObjectId('5b45aab564aa15b0fbea912e'),
#   'name': 'item 238',
#   'price': 26369},
#  {'_id': ObjectId('5b45aab564aa15b0fbea912f'),
#   'name': 'item 239',
#   'price': 32839},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9130'),
#   'name': 'item 240',
#   'price': 46199},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9131'),
#   'name': 'item 241',
#   'price': 27084},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9132'),
#   'name': 'item 242',
#   'price': 43069},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9133'),
#   'name': 'item 243',
#   'price': 22416},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9134'),
#   'name': 'item 244',
#   'price': 25991},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9135'),
#   'name': 'item 245',
#   'price': 32169},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9136'),
#   'name': 'item 246',
#   'price': 1769},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9137'),
#   'name': 'item 247',
#   'price': 8744},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9138'),
#   'name': 'item 248',
#   'price': 44128},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9139'),
#   'name': 'item 249',
#   'price': 6751},
#  {'_id': ObjectId('5b45aab564aa15b0fbea913a'),
#   'name': 'item 250',
#   'price': 37962},
#  {'_id': ObjectId('5b45aab564aa15b0fbea913b'),
#   'name': 'item 251',
#   'price': 36695},
#  {'_id': ObjectId('5b45aab564aa15b0fbea913c'),
#   'name': 'item 252',
#   'price': 18913},
#  {'_id': ObjectId('5b45aab564aa15b0fbea913d'),
#   'name': 'item 253',
#   'price': 46142},
#  {'_id': ObjectId('5b45aab564aa15b0fbea913e'),
#   'name': 'item 254',
#   'price': 15408},
#  {'_id': ObjectId('5b45aab564aa15b0fbea913f'),
#   'name': 'item 255',
#   'price': 25501},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9140'),
#   'name': 'item 256',
#   'price': 10658},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9141'),
#   'name': 'item 257',
#   'price': 724},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9142'),
#   'name': 'item 258',
#   'price': 17213},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9143'),
#   'name': 'item 259',
#   'price': 13424},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9144'),
#   'name': 'item 260',
#   'price': 7039},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9145'),
#   'name': 'item 261',
#   'price': 37073},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9146'),
#   'name': 'item 262',
#   'price': 46985},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9147'),
#   'name': 'item 263',
#   'price': 49586},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9148'),
#   'name': 'item 264',
#   'price': 16272},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9149'),
#   'name': 'item 265',
#   'price': 34504},
#  {'_id': ObjectId('5b45aab564aa15b0fbea914a'),
#   'name': 'item 266',
#   'price': 45352},
#  {'_id': ObjectId('5b45aab564aa15b0fbea914b'),
#   'name': 'item 267',
#   'price': 21668},
#  {'_id': ObjectId('5b45aab564aa15b0fbea914c'),
#   'name': 'item 268',
#   'price': 8616},
#  {'_id': ObjectId('5b45aab564aa15b0fbea914d'),
#   'name': 'item 269',
#   'price': 5802},
#  {'_id': ObjectId('5b45aab564aa15b0fbea914e'),
#   'name': 'item 270',
#   'price': 2825},
#  {'_id': ObjectId('5b45aab564aa15b0fbea914f'),
#   'name': 'item 271',
#   'price': 47349},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9150'),
#   'name': 'item 272',
#   'price': 1927},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9151'),
#   'name': 'item 273',
#   'price': 37493},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9152'),
#   'name': 'item 274',
#   'price': 28446},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9153'),
#   'name': 'item 275',
#   'price': 36462},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9154'),
#   'name': 'item 276',
#   'price': 45443},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9155'),
#   'name': 'item 277',
#   'price': 9207},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9156'),
#   'name': 'item 278',
#   'price': 46847},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9157'),
#   'name': 'item 279',
#   'price': 14722},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9158'),
#   'name': 'item 280',
#   'price': 7745},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9159'),
#   'name': 'item 281',
#   'price': 2288},
#  {'_id': ObjectId('5b45aab564aa15b0fbea915a'),
#   'name': 'item 282',
#   'price': 15105},
#  {'_id': ObjectId('5b45aab564aa15b0fbea915b'),
#   'name': 'item 283',
#   'price': 24560},
#  {'_id': ObjectId('5b45aab564aa15b0fbea915c'),
#   'name': 'item 284',
#   'price': 25690},
#  {'_id': ObjectId('5b45aab564aa15b0fbea915d'),
#   'name': 'item 285',
#   'price': 42786},
#  {'_id': ObjectId('5b45aab564aa15b0fbea915e'),
#   'name': 'item 286',
#   'price': 36096},
#  {'_id': ObjectId('5b45aab564aa15b0fbea915f'),
#   'name': 'item 287',
#   'price': 26591},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9160'),
#   'name': 'item 288',
#   'price': 39520},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9161'),
#   'name': 'item 289',
#   'price': 41833},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9162'),
#   'name': 'item 290',
#   'price': 12834},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9163'),
#   'name': 'item 291',
#   'price': 29625},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9164'),
#   'name': 'item 292',
#   'price': 5567},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9165'),
#   'name': 'item 293',
#   'price': 47729},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9166'),
#   'name': 'item 294',
#   'price': 13903},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9167'),
#   'name': 'item 295',
#   'price': 12433},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9168'),
#   'name': 'item 296',
#   'price': 48902},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9169'),
#   'name': 'item 297',
#   'price': 20168},
#  {'_id': ObjectId('5b45aab564aa15b0fbea916a'),
#   'name': 'item 298',
#   'price': 2272},
#  {'_id': ObjectId('5b45aab564aa15b0fbea916b'),
#   'name': 'item 299',
#   'price': 49319},
#  {'_id': ObjectId('5b45aab564aa15b0fbea916c'),
#   'name': 'item 300',
#   'price': 48066},
#  {'_id': ObjectId('5b45aab564aa15b0fbea916d'),
#   'name': 'item 301',
#   'price': 29229},
#  {'_id': ObjectId('5b45aab564aa15b0fbea916e'),
#   'name': 'item 302',
#   'price': 37499},
#  {'_id': ObjectId('5b45aab564aa15b0fbea916f'),
#   'name': 'item 303',
#   'price': 1828},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9170'),
#   'name': 'item 304',
#   'price': 36706},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9171'),
#   'name': 'item 305',
#   'price': 6586},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9172'),
#   'name': 'item 306',
#   'price': 15432},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9173'),
#   'name': 'item 307',
#   'price': 10813},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9174'),
#   'name': 'item 308',
#   'price': 36291},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9175'),
#   'name': 'item 309',
#   'price': 34239},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9176'),
#   'name': 'item 310',
#   'price': 41661},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9177'),
#   'name': 'item 311',
#   'price': 35193},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9178'),
#   'name': 'item 312',
#   'price': 29585},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9179'),
#   'name': 'item 313',
#   'price': 49021},
#  {'_id': ObjectId('5b45aab564aa15b0fbea917a'),
#   'name': 'item 314',
#   'price': 20466},
#  {'_id': ObjectId('5b45aab564aa15b0fbea917b'),
#   'name': 'item 315',
#   'price': 33984},
#  {'_id': ObjectId('5b45aab564aa15b0fbea917c'),
#   'name': 'item 316',
#   'price': 17741},
#  {'_id': ObjectId('5b45aab564aa15b0fbea917d'),
#   'name': 'item 317',
#   'price': 16209},
#  {'_id': ObjectId('5b45aab564aa15b0fbea917e'),
#   'name': 'item 318',
#   'price': 15488},
#  {'_id': ObjectId('5b45aab564aa15b0fbea917f'),
#   'name': 'item 319',
#   'price': 23548},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9180'),
#   'name': 'item 320',
#   'price': 41652},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9181'),
#   'name': 'item 321',
#   'price': 17384},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9182'),
#   'name': 'item 322',
#   'price': 40890},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9183'),
#   'name': 'item 323',
#   'price': 17658},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9184'),
#   'name': 'item 324',
#   'price': 34013},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9185'),
#   'name': 'item 325',
#   'price': 27337},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9186'),
#   'name': 'item 326',
#   'price': 10411},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9187'),
#   'name': 'item 327',
#   'price': 7667},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9188'),
#   'name': 'item 328',
#   'price': 19859},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9189'),
#   'name': 'item 329',
#   'price': 7442},
#  {'_id': ObjectId('5b45aab564aa15b0fbea918a'),
#   'name': 'item 330',
#   'price': 36903},
#  {'_id': ObjectId('5b45aab564aa15b0fbea918b'),
#   'name': 'item 331',
#   'price': 41964},
#  {'_id': ObjectId('5b45aab564aa15b0fbea918c'),
#   'name': 'item 332',
#   'price': 17508},
#  {'_id': ObjectId('5b45aab564aa15b0fbea918d'),
#   'name': 'item 333',
#   'price': 47200},
#  {'_id': ObjectId('5b45aab564aa15b0fbea918e'),
#   'name': 'item 334',
#   'price': 31255},
#  {'_id': ObjectId('5b45aab564aa15b0fbea918f'),
#   'name': 'item 335',
#   'price': 8578},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9190'),
#   'name': 'item 336',
#   'price': 1494},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9191'),
#   'name': 'item 337',
#   'price': 2894},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9192'),
#   'name': 'item 338',
#   'price': 15148},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9193'),
#   'name': 'item 339',
#   'price': 48235},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9194'),
#   'name': 'item 340',
#   'price': 21000},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9195'),
#   'name': 'item 341',
#   'price': 44800},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9196'),
#   'name': 'item 342',
#   'price': 10487},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9197'),
#   'name': 'item 343',
#   'price': 45483},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9198'),
#   'name': 'item 344',
#   'price': 11030},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9199'),
#   'name': 'item 345',
#   'price': 25335},
#  {'_id': ObjectId('5b45aab564aa15b0fbea919a'),
#   'name': 'item 346',
#   'price': 17510},
#  {'_id': ObjectId('5b45aab564aa15b0fbea919b'),
#   'name': 'item 347',
#   'price': 7521},
#  {'_id': ObjectId('5b45aab564aa15b0fbea919c'),
#   'name': 'item 348',
#   'price': 19059},
#  {'_id': ObjectId('5b45aab564aa15b0fbea919d'),
#   'name': 'item 349',
#   'price': 44822},
#  {'_id': ObjectId('5b45aab564aa15b0fbea919e'),
#   'name': 'item 350',
#   'price': 38679},
#  {'_id': ObjectId('5b45aab564aa15b0fbea919f'),
#   'name': 'item 351',
#   'price': 40716},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a0'),
#   'name': 'item 352',
#   'price': 253},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a1'),
#   'name': 'item 353',
#   'price': 35199},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a2'),
#   'name': 'item 354',
#   'price': 9579},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a3'),
#   'name': 'item 355',
#   'price': 45072},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a4'),
#   'name': 'item 356',
#   'price': 16731},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a5'),
#   'name': 'item 357',
#   'price': 44488},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a6'),
#   'name': 'item 358',
#   'price': 5280},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a7'),
#   'name': 'item 359',
#   'price': 42821},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a8'),
#   'name': 'item 360',
#   'price': 31260},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91a9'),
#   'name': 'item 361',
#   'price': 37435},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91aa'),
#   'name': 'item 362',
#   'price': 29239},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ab'),
#   'name': 'item 363',
#   'price': 20297},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ac'),
#   'name': 'item 364',
#   'price': 44152},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ad'),
#   'name': 'item 365',
#   'price': 9937},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ae'),
#   'name': 'item 366',
#   'price': 21721},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91af'),
#   'name': 'item 367',
#   'price': 46012},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b0'),
#   'name': 'item 368',
#   'price': 29041},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b1'),
#   'name': 'item 369',
#   'price': 23362},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b2'),
#   'name': 'item 370',
#   'price': 17426},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b3'),
#   'name': 'item 371',
#   'price': 19274},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b4'),
#   'name': 'item 372',
#   'price': 29317},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b5'),
#   'name': 'item 373',
#   'price': 43994},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b6'),
#   'name': 'item 374',
#   'price': 36170},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b7'),
#   'name': 'item 375',
#   'price': 19409},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b8'),
#   'name': 'item 376',
#   'price': 22869},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91b9'),
#   'name': 'item 377',
#   'price': 14986},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ba'),
#   'name': 'item 378',
#   'price': 11053},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91bb'),
#   'name': 'item 379',
#   'price': 4667},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91bc'),
#   'name': 'item 380',
#   'price': 1572},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91bd'),
#   'name': 'item 381',
#   'price': 36138},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91be'),
#   'name': 'item 382',
#   'price': 9710},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91bf'),
#   'name': 'item 383',
#   'price': 3681},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c0'),
#   'name': 'item 384',
#   'price': 27903},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c1'),
#   'name': 'item 385',
#   'price': 44838},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c2'),
#   'name': 'item 386',
#   'price': 335},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c3'),
#   'name': 'item 387',
#   'price': 12641},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c4'),
#   'name': 'item 388',
#   'price': 38865},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c5'),
#   'name': 'item 389',
#   'price': 43662},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c6'),
#   'name': 'item 390',
#   'price': 18536},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c7'),
#   'name': 'item 391',
#   'price': 30798},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c8'),
#   'name': 'item 392',
#   'price': 45566},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91c9'),
#   'name': 'item 393',
#   'price': 6794},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ca'),
#   'name': 'item 394',
#   'price': 36335},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91cb'),
#   'name': 'item 395',
#   'price': 20674},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91cc'),
#   'name': 'item 396',
#   'price': 12121},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91cd'),
#   'name': 'item 397',
#   'price': 34108},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ce'),
#   'name': 'item 398',
#   'price': 35571},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91cf'),
#   'name': 'item 399',
#   'price': 23908},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d0'),
#   'name': 'item 400',
#   'price': 10891},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d1'),
#   'name': 'item 401',
#   'price': 9706},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d2'),
#   'name': 'item 402',
#   'price': 42107},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d3'),
#   'name': 'item 403',
#   'price': 47024},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d4'),
#   'name': 'item 404',
#   'price': 39805},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d5'),
#   'name': 'item 405',
#   'price': 43658},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d6'),
#   'name': 'item 406',
#   'price': 8458},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d7'),
#   'name': 'item 407',
#   'price': 45001},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d8'),
#   'name': 'item 408',
#   'price': 13699},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91d9'),
#   'name': 'item 409',
#   'price': 47447},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91da'),
#   'name': 'item 410',
#   'price': 33396},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91db'),
#   'name': 'item 411',
#   'price': 13997},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91dc'),
#   'name': 'item 412',
#   'price': 9167},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91dd'),
#   'name': 'item 413',
#   'price': 28251},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91de'),
#   'name': 'item 414',
#   'price': 41607},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91df'),
#   'name': 'item 415',
#   'price': 96},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e0'),
#   'name': 'item 416',
#   'price': 17692},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e1'),
#   'name': 'item 417',
#   'price': 9974},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e2'),
#   'name': 'item 418',
#   'price': 36443},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e3'),
#   'name': 'item 419',
#   'price': 44577},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e4'),
#   'name': 'item 420',
#   'price': 49967},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e5'),
#   'name': 'item 421',
#   'price': 31164},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e6'),
#   'name': 'item 422',
#   'price': 7861},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e7'),
#   'name': 'item 423',
#   'price': 21927},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e8'),
#   'name': 'item 424',
#   'price': 7154},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91e9'),
#   'name': 'item 425',
#   'price': 11214},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ea'),
#   'name': 'item 426',
#   'price': 47511},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91eb'),
#   'name': 'item 427',
#   'price': 40433},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ec'),
#   'name': 'item 428',
#   'price': 17989},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ed'),
#   'name': 'item 429',
#   'price': 40198},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ee'),
#   'name': 'item 430',
#   'price': 36152},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ef'),
#   'name': 'item 431',
#   'price': 35239},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f0'),
#   'name': 'item 432',
#   'price': 47458},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f1'),
#   'name': 'item 433',
#   'price': 19928},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f2'),
#   'name': 'item 434',
#   'price': 35157},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f3'),
#   'name': 'item 435',
#   'price': 7141},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f4'),
#   'name': 'item 436',
#   'price': 10788},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f5'),
#   'name': 'item 437',
#   'price': 14875},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f6'),
#   'name': 'item 438',
#   'price': 6302},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f7'),
#   'name': 'item 439',
#   'price': 48318},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f8'),
#   'name': 'item 440',
#   'price': 4179},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91f9'),
#   'name': 'item 441',
#   'price': 23536},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91fa'),
#   'name': 'item 442',
#   'price': 30032},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91fb'),
#   'name': 'item 443',
#   'price': 7611},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91fc'),
#   'name': 'item 444',
#   'price': 39585},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91fd'),
#   'name': 'item 445',
#   'price': 48848},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91fe'),
#   'name': 'item 446',
#   'price': 4708},
#  {'_id': ObjectId('5b45aab564aa15b0fbea91ff'),
#   'name': 'item 447',
#   'price': 7419},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9200'),
#   'name': 'item 448',
#   'price': 5185},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9201'),
#   'name': 'item 449',
#   'price': 39973},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9202'),
#   'name': 'item 450',
#   'price': 49153},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9203'),
#   'name': 'item 451',
#   'price': 1151},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9204'),
#   'name': 'item 452',
#   'price': 10071},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9205'),
#   'name': 'item 453',
#   'price': 15444},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9206'),
#   'name': 'item 454',
#   'price': 23096},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9207'),
#   'name': 'item 455',
#   'price': 36625},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9208'),
#   'name': 'item 456',
#   'price': 5319},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9209'),
#   'name': 'item 457',
#   'price': 16500},
#  {'_id': ObjectId('5b45aab564aa15b0fbea920a'),
#   'name': 'item 458',
#   'price': 12270},
#  {'_id': ObjectId('5b45aab564aa15b0fbea920b'),
#   'name': 'item 459',
#   'price': 36626},
#  {'_id': ObjectId('5b45aab564aa15b0fbea920c'),
#   'name': 'item 460',
#   'price': 4814},
#  {'_id': ObjectId('5b45aab564aa15b0fbea920d'),
#   'name': 'item 461',
#   'price': 37964},
#  {'_id': ObjectId('5b45aab564aa15b0fbea920e'),
#   'name': 'item 462',
#   'price': 34539},
#  {'_id': ObjectId('5b45aab564aa15b0fbea920f'),
#   'name': 'item 463',
#   'price': 20862},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9210'),
#   'name': 'item 464',
#   'price': 48320},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9211'),
#   'name': 'item 465',
#   'price': 49481},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9212'),
#   'name': 'item 466',
#   'price': 45327},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9213'),
#   'name': 'item 467',
#   'price': 11157},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9214'),
#   'name': 'item 468',
#   'price': 27971},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9215'),
#   'name': 'item 469',
#   'price': 33199},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9216'),
#   'name': 'item 470',
#   'price': 24242},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9217'),
#   'name': 'item 471',
#   'price': 692},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9218'),
#   'name': 'item 472',
#   'price': 34199},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9219'),
#   'name': 'item 473',
#   'price': 31918},
#  {'_id': ObjectId('5b45aab564aa15b0fbea921a'),
#   'name': 'item 474',
#   'price': 10507},
#  {'_id': ObjectId('5b45aab564aa15b0fbea921b'),
#   'name': 'item 475',
#   'price': 44722},
#  {'_id': ObjectId('5b45aab564aa15b0fbea921c'),
#   'name': 'item 476',
#   'price': 30800},
#  {'_id': ObjectId('5b45aab564aa15b0fbea921d'),
#   'name': 'item 477',
#   'price': 33096},
#  {'_id': ObjectId('5b45aab564aa15b0fbea921e'),
#   'name': 'item 478',
#   'price': 26013},
#  {'_id': ObjectId('5b45aab564aa15b0fbea921f'),
#   'name': 'item 479',
#   'price': 44798},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9220'),
#   'name': 'item 480',
#   'price': 45115},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9221'),
#   'name': 'item 481',
#   'price': 49130},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9222'),
#   'name': 'item 482',
#   'price': 21458},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9223'),
#   'name': 'item 483',
#   'price': 29586},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9224'),
#   'name': 'item 484',
#   'price': 35131},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9225'),
#   'name': 'item 485',
#   'price': 8739},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9226'),
#   'name': 'item 486',
#   'price': 12662},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9227'),
#   'name': 'item 487',
#   'price': 40631},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9228'),
#   'name': 'item 488',
#   'price': 3935},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9229'),
#   'name': 'item 489',
#   'price': 48497},
#  {'_id': ObjectId('5b45aab564aa15b0fbea922a'),
#   'name': 'item 490',
#   'price': 6229},
#  {'_id': ObjectId('5b45aab564aa15b0fbea922b'),
#   'name': 'item 491',
#   'price': 27875},
#  {'_id': ObjectId('5b45aab564aa15b0fbea922c'),
#   'name': 'item 492',
#   'price': 7807},
#  {'_id': ObjectId('5b45aab564aa15b0fbea922d'),
#   'name': 'item 493',
#   'price': 14092},
#  {'_id': ObjectId('5b45aab564aa15b0fbea922e'),
#   'name': 'item 494',
#   'price': 39462},
#  {'_id': ObjectId('5b45aab564aa15b0fbea922f'),
#   'name': 'item 495',
#   'price': 14611},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9230'),
#   'name': 'item 496',
#   'price': 18636},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9231'),
#   'name': 'item 497',
#   'price': 22458},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9232'),
#   'name': 'item 498',
#   'price': 15949},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9233'),
#   'name': 'item 499',
#   'price': 47155},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9234'),
#   'name': 'item 500',
#   'price': 48082},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9235'),
#   'name': 'item 501',
#   'price': 41534},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9236'),
#   'name': 'item 502',
#   'price': 9938},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9237'),
#   'name': 'item 503',
#   'price': 36793},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9238'),
#   'name': 'item 504',
#   'price': 24093},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9239'),
#   'name': 'item 505',
#   'price': 16173},
#  {'_id': ObjectId('5b45aab564aa15b0fbea923a'),
#   'name': 'item 506',
#   'price': 25179},
#  {'_id': ObjectId('5b45aab564aa15b0fbea923b'),
#   'name': 'item 507',
#   'price': 14600},
#  {'_id': ObjectId('5b45aab564aa15b0fbea923c'),
#   'name': 'item 508',
#   'price': 1623},
#  {'_id': ObjectId('5b45aab564aa15b0fbea923d'),
#   'name': 'item 509',
#   'price': 42312},
#  {'_id': ObjectId('5b45aab564aa15b0fbea923e'),
#   'name': 'item 510',
#   'price': 33288},
#  {'_id': ObjectId('5b45aab564aa15b0fbea923f'),
#   'name': 'item 511',
#   'price': 45756},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9240'),
#   'name': 'item 512',
#   'price': 35462},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9241'),
#   'name': 'item 513',
#   'price': 7272},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9242'),
#   'name': 'item 514',
#   'price': 41786},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9243'),
#   'name': 'item 515',
#   'price': 37798},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9244'),
#   'name': 'item 516',
#   'price': 2151},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9245'),
#   'name': 'item 517',
#   'price': 3412},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9246'),
#   'name': 'item 518',
#   'price': 23696},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9247'),
#   'name': 'item 519',
#   'price': 47351},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9248'),
#   'name': 'item 520',
#   'price': 5099},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9249'),
#   'name': 'item 521',
#   'price': 20106},
#  {'_id': ObjectId('5b45aab564aa15b0fbea924a'),
#   'name': 'item 522',
#   'price': 2019},
#  {'_id': ObjectId('5b45aab564aa15b0fbea924b'),
#   'name': 'item 523',
#   'price': 26395},
#  {'_id': ObjectId('5b45aab564aa15b0fbea924c'),
#   'name': 'item 524',
#   'price': 19469},
#  {'_id': ObjectId('5b45aab564aa15b0fbea924d'),
#   'name': 'item 525',
#   'price': 17314},
#  {'_id': ObjectId('5b45aab564aa15b0fbea924e'),
#   'name': 'item 526',
#   'price': 2569},
#  {'_id': ObjectId('5b45aab564aa15b0fbea924f'),
#   'name': 'item 527',
#   'price': 18711},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9250'),
#   'name': 'item 528',
#   'price': 39830},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9251'),
#   'name': 'item 529',
#   'price': 30308},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9252'),
#   'name': 'item 530',
#   'price': 34902},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9253'),
#   'name': 'item 531',
#   'price': 49016},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9254'),
#   'name': 'item 532',
#   'price': 14611},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9255'),
#   'name': 'item 533',
#   'price': 24847},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9256'),
#   'name': 'item 534',
#   'price': 14225},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9257'),
#   'name': 'item 535',
#   'price': 20159},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9258'),
#   'name': 'item 536',
#   'price': 20586},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9259'),
#   'name': 'item 537',
#   'price': 37629},
#  {'_id': ObjectId('5b45aab564aa15b0fbea925a'),
#   'name': 'item 538',
#   'price': 21313},
#  {'_id': ObjectId('5b45aab564aa15b0fbea925b'),
#   'name': 'item 539',
#   'price': 41221},
#  {'_id': ObjectId('5b45aab564aa15b0fbea925c'),
#   'name': 'item 540',
#   'price': 42183},
#  {'_id': ObjectId('5b45aab564aa15b0fbea925d'),
#   'name': 'item 541',
#   'price': 44231},
#  {'_id': ObjectId('5b45aab564aa15b0fbea925e'),
#   'name': 'item 542',
#   'price': 11662},
#  {'_id': ObjectId('5b45aab564aa15b0fbea925f'),
#   'name': 'item 543',
#   'price': 4794},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9260'),
#   'name': 'item 544',
#   'price': 11700},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9261'),
#   'name': 'item 545',
#   'price': 17319},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9262'),
#   'name': 'item 546',
#   'price': 17497},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9263'),
#   'name': 'item 547',
#   'price': 22543},
# ...
#  {'_id': ObjectId('5b45aab564aa15b0fbea9372'),
#   'name': 'item 818',
#   'price': 13810},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9373'),
#   'name': 'item 819',
#   'price': 40334},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9374'),
#   'name': 'item 820',
#   'price': 7349},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9375'),
#   'name': 'item 821',
#   'price': 45886},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9376'),
#   'name': 'item 822',
#   'price': 9799},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9377'),
#   'name': 'item 823',
#   'price': 3140},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9378'),
#   'name': 'item 824',
#   'price': 28793},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9379'),
#   'name': 'item 825',
#   'price': 4592},
#  {'_id': ObjectId('5b45aab564aa15b0fbea937a'),
#   'name': 'item 826',
#   'price': 5509},
#  {'_id': ObjectId('5b45aab564aa15b0fbea937b'),
#   'name': 'item 827',
#   'price': 41584},
#  {'_id': ObjectId('5b45aab564aa15b0fbea937c'),
#   'name': 'item 828',
#   'price': 17023},
#  {'_id': ObjectId('5b45aab564aa15b0fbea937d'),
#   'name': 'item 829',
#   'price': 14445},
#  {'_id': ObjectId('5b45aab564aa15b0fbea937e'),
#   'name': 'item 830',
#   'price': 23345},
#  {'_id': ObjectId('5b45aab564aa15b0fbea937f'),
#   'name': 'item 831',
#   'price': 25673},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9380'),
#   'name': 'item 832',
#   'price': 19568},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9381'),
#   'name': 'item 833',
#   'price': 13876},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9382'),
#   'name': 'item 834',
#   'price': 48287},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9383'),
#   'name': 'item 835',
#   'price': 15296},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9384'),
#   'name': 'item 836',
#   'price': 11024},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9385'),
#   'name': 'item 837',
#   'price': 683},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9386'),
#   'name': 'item 838',
#   'price': 41816},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9387'),
#   'name': 'item 839',
#   'price': 34239},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9388'),
#   'name': 'item 840',
#   'price': 12901},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9389'),
#   'name': 'item 841',
#   'price': 37160},
#  {'_id': ObjectId('5b45aab564aa15b0fbea938a'),
#   'name': 'item 842',
#   'price': 8803},
#  {'_id': ObjectId('5b45aab564aa15b0fbea938b'),
#   'name': 'item 843',
#   'price': 46821},
#  {'_id': ObjectId('5b45aab564aa15b0fbea938c'),
#   'name': 'item 844',
#   'price': 48362},
#  {'_id': ObjectId('5b45aab564aa15b0fbea938d'),
#   'name': 'item 845',
#   'price': 38650},
#  {'_id': ObjectId('5b45aab564aa15b0fbea938e'),
#   'name': 'item 846',
#   'price': 49771},
#  {'_id': ObjectId('5b45aab564aa15b0fbea938f'),
#   'name': 'item 847',
#   'price': 16494},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9390'),
#   'name': 'item 848',
#   'price': 12218},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9391'),
#   'name': 'item 849',
#   'price': 26969},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9392'),
#   'name': 'item 850',
#   'price': 8522},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9393'),
#   'name': 'item 851',
#   'price': 4192},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9394'),
#   'name': 'item 852',
#   'price': 44688},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9395'),
#   'name': 'item 853',
#   'price': 38170},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9396'),
#   'name': 'item 854',
#   'price': 13966},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9397'),
#   'name': 'item 855',
#   'price': 12194},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9398'),
#   'name': 'item 856',
#   'price': 33693},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9399'),
#   'name': 'item 857',
#   'price': 16348},
#  {'_id': ObjectId('5b45aab564aa15b0fbea939a'),
#   'name': 'item 858',
#   'price': 2390},
#  {'_id': ObjectId('5b45aab564aa15b0fbea939b'),
#   'name': 'item 859',
#   'price': 30606},
#  {'_id': ObjectId('5b45aab564aa15b0fbea939c'),
#   'name': 'item 860',
#   'price': 30637},
#  {'_id': ObjectId('5b45aab564aa15b0fbea939d'),
#   'name': 'item 861',
#   'price': 48610},
#  {'_id': ObjectId('5b45aab564aa15b0fbea939e'),
#   'name': 'item 862',
#   'price': 45313},
#  {'_id': ObjectId('5b45aab564aa15b0fbea939f'),
#   'name': 'item 863',
#   'price': 17457},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a0'),
#   'name': 'item 864',
#   'price': 13148},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a1'),
#   'name': 'item 865',
#   'price': 24286},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a2'),
#   'name': 'item 866',
#   'price': 31078},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a3'),
#   'name': 'item 867',
#   'price': 22642},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a4'),
#   'name': 'item 868',
#   'price': 6792},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a5'),
#   'name': 'item 869',
#   'price': 24344},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a6'),
#   'name': 'item 870',
#   'price': 42765},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a7'),
#   'name': 'item 871',
#   'price': 5696},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a8'),
#   'name': 'item 872',
#   'price': 22556},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93a9'),
#   'name': 'item 873',
#   'price': 39245},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93aa'),
#   'name': 'item 874',
#   'price': 21432},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ab'),
#   'name': 'item 875',
#   'price': 23132},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ac'),
#   'name': 'item 876',
#   'price': 41393},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ad'),
#   'name': 'item 877',
#   'price': 6304},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ae'),
#   'name': 'item 878',
#   'price': 14563},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93af'),
#   'name': 'item 879',
#   'price': 40158},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b0'),
#   'name': 'item 880',
#   'price': 48892},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b1'),
#   'name': 'item 881',
#   'price': 6172},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b2'),
#   'name': 'item 882',
#   'price': 44483},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b3'),
#   'name': 'item 883',
#   'price': 36797},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b4'),
#   'name': 'item 884',
#   'price': 26561},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b5'),
#   'name': 'item 885',
#   'price': 24000},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b6'),
#   'name': 'item 886',
#   'price': 45404},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b7'),
#   'name': 'item 887',
#   'price': 27170},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b8'),
#   'name': 'item 888',
#   'price': 9134},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93b9'),
#   'name': 'item 889',
#   'price': 27425},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ba'),
#   'name': 'item 890',
#   'price': 20595},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93bb'),
#   'name': 'item 891',
#   'price': 7284},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93bc'),
#   'name': 'item 892',
#   'price': 1830},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93bd'),
#   'name': 'item 893',
#   'price': 9146},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93be'),
#   'name': 'item 894',
#   'price': 23460},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93bf'),
#   'name': 'item 895',
#   'price': 25555},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c0'),
#   'name': 'item 896',
#   'price': 10960},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c1'),
#   'name': 'item 897',
#   'price': 23844},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c2'),
#   'name': 'item 898',
#   'price': 49910},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c3'),
#   'name': 'item 899',
#   'price': 40391},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c4'),
#   'name': 'item 900',
#   'price': 17618},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c5'),
#   'name': 'item 901',
#   'price': 1537},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c6'),
#   'name': 'item 902',
#   'price': 28575},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c7'),
#   'name': 'item 903',
#   'price': 39073},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c8'),
#   'name': 'item 904',
#   'price': 2103},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93c9'),
#   'name': 'item 905',
#   'price': 30154},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ca'),
#   'name': 'item 906',
#   'price': 4732},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93cb'),
#   'name': 'item 907',
#   'price': 43352},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93cc'),
#   'name': 'item 908',
#   'price': 13243},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93cd'),
#   'name': 'item 909',
#   'price': 38850},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ce'),
#   'name': 'item 910',
#   'price': 4317},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93cf'),
#   'name': 'item 911',
#   'price': 47214},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d0'),
#   'name': 'item 912',
#   'price': 27221},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d1'),
#   'name': 'item 913',
#   'price': 15337},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d2'),
#   'name': 'item 914',
#   'price': 30855},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d3'),
#   'name': 'item 915',
#   'price': 19754},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d4'),
#   'name': 'item 916',
#   'price': 21732},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d5'),
#   'name': 'item 917',
#   'price': 11569},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d6'),
#   'name': 'item 918',
#   'price': 16011},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d7'),
#   'name': 'item 919',
#   'price': 757},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d8'),
#   'name': 'item 920',
#   'price': 13278},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93d9'),
#   'name': 'item 921',
#   'price': 43024},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93da'),
#   'name': 'item 922',
#   'price': 12305},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93db'),
#   'name': 'item 923',
#   'price': 29030},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93dc'),
#   'name': 'item 924',
#   'price': 44292},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93dd'),
#   'name': 'item 925',
#   'price': 37582},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93de'),
#   'name': 'item 926',
#   'price': 31046},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93df'),
#   'name': 'item 927',
#   'price': 17652},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e0'),
#   'name': 'item 928',
#   'price': 37071},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e1'),
#   'name': 'item 929',
#   'price': 42596},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e2'),
#   'name': 'item 930',
#   'price': 32390},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e3'),
#   'name': 'item 931',
#   'price': 39134},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e4'),
#   'name': 'item 932',
#   'price': 38775},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e5'),
#   'name': 'item 933',
#   'price': 2663},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e6'),
#   'name': 'item 934',
#   'price': 14989},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e7'),
#   'name': 'item 935',
#   'price': 39473},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e8'),
#   'name': 'item 936',
#   'price': 6904},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93e9'),
#   'name': 'item 937',
#   'price': 48712},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ea'),
#   'name': 'item 938',
#   'price': 27767},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93eb'),
#   'name': 'item 939',
#   'price': 20833},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ec'),
#   'name': 'item 940',
#   'price': 11436},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ed'),
#   'name': 'item 941',
#   'price': 49620},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ee'),
#   'name': 'item 942',
#   'price': 19973},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ef'),
#   'name': 'item 943',
#   'price': 20029},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f0'),
#   'name': 'item 944',
#   'price': 19172},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f1'),
#   'name': 'item 945',
#   'price': 16809},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f2'),
#   'name': 'item 946',
#   'price': 46387},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f3'),
#   'name': 'item 947',
#   'price': 45123},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f4'),
#   'name': 'item 948',
#   'price': 33458},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f5'),
#   'name': 'item 949',
#   'price': 29537},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f6'),
#   'name': 'item 950',
#   'price': 47380},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f7'),
#   'name': 'item 951',
#   'price': 24747},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f8'),
#   'name': 'item 952',
#   'price': 13256},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93f9'),
#   'name': 'item 953',
#   'price': 30642},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93fa'),
#   'name': 'item 954',
#   'price': 14173},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93fb'),
#   'name': 'item 955',
#   'price': 43724},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93fc'),
#   'name': 'item 956',
#   'price': 14395},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93fd'),
#   'name': 'item 957',
#   'price': 41316},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93fe'),
#   'name': 'item 958',
#   'price': 26172},
#  {'_id': ObjectId('5b45aab564aa15b0fbea93ff'),
#   'name': 'item 959',
#   'price': 5697},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9400'),
#   'name': 'item 960',
#   'price': 17311},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9401'),
#   'name': 'item 961',
#   'price': 40931},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9402'),
#   'name': 'item 962',
#   'price': 15617},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9403'),
#   'name': 'item 963',
#   'price': 8577},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9404'),
#   'name': 'item 964',
#   'price': 41819},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9405'),
#   'name': 'item 965',
#   'price': 40717},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9406'),
#   'name': 'item 966',
#   'price': 30733},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9407'),
#   'name': 'item 967',
#   'price': 20835},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9408'),
#   'name': 'item 968',
#   'price': 18267},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9409'),
#   'name': 'item 969',
#   'price': 27577},
#  {'_id': ObjectId('5b45aab564aa15b0fbea940a'),
#   'name': 'item 970',
#   'price': 42091},
#  {'_id': ObjectId('5b45aab564aa15b0fbea940b'),
#   'name': 'item 971',
#   'price': 41888},
#  {'_id': ObjectId('5b45aab564aa15b0fbea940c'),
#   'name': 'item 972',
#   'price': 994},
#  {'_id': ObjectId('5b45aab564aa15b0fbea940d'),
#   'name': 'item 973',
#   'price': 20647},
#  {'_id': ObjectId('5b45aab564aa15b0fbea940e'),
#   'name': 'item 974',
#   'price': 21972},
#  {'_id': ObjectId('5b45aab564aa15b0fbea940f'),
#   'name': 'item 975',
#   'price': 20819},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9410'),
#   'name': 'item 976',
#   'price': 21130},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9411'),
#   'name': 'item 977',
#   'price': 11825},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9412'),
#   'name': 'item 978',
#   'price': 43797},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9413'),
#   'name': 'item 979',
#   'price': 12537},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9414'),
#   'name': 'item 980',
#   'price': 16103},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9415'),
#   'name': 'item 981',
#   'price': 13255},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9416'),
#   'name': 'item 982',
#   'price': 43401},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9417'),
#   'name': 'item 983',
#   'price': 42667},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9418'),
#   'name': 'item 984',
#   'price': 5158},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9419'),
#   'name': 'item 985',
#   'price': 20096},
#  {'_id': ObjectId('5b45aab564aa15b0fbea941a'),
#   'name': 'item 986',
#   'price': 12084},
#  {'_id': ObjectId('5b45aab564aa15b0fbea941b'),
#   'name': 'item 987',
#   'price': 21235},
#  {'_id': ObjectId('5b45aab564aa15b0fbea941c'),
#   'name': 'item 988',
#   'price': 469},
#  {'_id': ObjectId('5b45aab564aa15b0fbea941d'),
#   'name': 'item 989',
#   'price': 31886},
#  {'_id': ObjectId('5b45aab564aa15b0fbea941e'),
#   'name': 'item 990',
#   'price': 12257},
#  {'_id': ObjectId('5b45aab564aa15b0fbea941f'),
#   'name': 'item 991',
#   'price': 40401},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9420'),
#   'name': 'item 992',
#   'price': 981},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9421'),
#   'name': 'item 993',
#   'price': 28528},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9422'),
#   'name': 'item 994',
#   'price': 32028},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9423'),
#   'name': 'item 995',
#   'price': 29957},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9424'),
#   'name': 'item 996',
#   'price': 49860},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9425'),
#   'name': 'item 997',
#   'price': 34003},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9426'),
#   'name': 'item 998',
#   'price': 47945},
#  {'_id': ObjectId('5b45aab564aa15b0fbea9427'),
#   'name': 'item 999',
#   'price': 14441},
#  ...]

# %%
result = item.find({})

# %%
i = list(result)

# %%
type(i)
# Out:
# list

# %%
i[0]
# Out:
# {'_id': ObjectId('5b45aab564aa15b0fbea9040'), 'name': 'item 0', 'price': 35326}

# %%
i[0]['name']
# Out:
# 'item 0'

# %%
newitem2 = {'name':"newitem2", 'price':float(10000), 'ratio':4.1}

# %%
item.insert_one(newitem2)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-55-0de5577d8186> in <module>()
# ----> 1 item.insert_one(newitem2)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
#     606                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 607                 bypass_doc_val, session)
#     608
#     609         ids = []
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     593
#     594         self.__database.client._retryable_write(
# --> 595             acknowledged, _insert_command, session)
#     596
#     597         if not isinstance(doc, RawBSONDocument):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1241         """Internal retryable write helper."""
#    1242         with self._tmp_session(session) as s:
# -> 1243             return self._retry_with_session(retryable, func, s, None)
#    1244
#    1245     def __reset_server(self, address):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1194                         # Reset the transaction id and retry the operation.
#    1195                         session._retry_transaction_id()
# -> 1196                     return func(session, sock_info, retryable)
#    1197             except ServerSelectionTimeoutError:
#    1198                 if is_retrying():
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     590                 retryable_write=retryable_write)
#     591
# --> 592             _check_write_command_response(result)
#     593
#     594         self.__database.client._retryable_write(
#
# ~\Anaconda3\lib\site-packages\pymongo\helpers.py in _check_write_command_response(result)
#     215     write_errors = result.get("writeErrors")
#     216     if write_errors:
# --> 217         _raise_last_write_error(write_errors)
#     218
#     219     error = result.get("writeConcernError")
#
# ~\Anaconda3\lib\site-packages\pymongo\helpers.py in _raise_last_write_error(write_errors)
#     196     error = write_errors[-1]
#     197     if error.get("code") == 11000:
# --> 198         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     199     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     200
#
# DuplicateKeyError: E11000 duplicate key error collection: test.item index: _id_ dup key: { : ObjectId('5b4eabe3b9723d5d1ce37767') }

# %% [markdown]
# ----------------------안댐 여기부터.. -----------------------

# %%
import requests
data = requests.get()
res

# %%
resStr = res.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-0ace7e4bc925> in <module>()
# ----> 1 resStr = res.read()
#
# NameError: name 'res' is not defined

# %%
from pymongo import MongoClient

# %%
client = MongoClient('localhost')

# %%
client.air.info.insert_many(resObj['list'])

# %%
result = client.air.info.find({})

# %%
for i in result:
    print(i)

# %%
from pprint
